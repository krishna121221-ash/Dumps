# %%
import sys
print('Python: {}'.format(sys.version))
# scipy
import scipy
print('scipy: {}'.format(scipy.__version__))
# numpy
import numpy
print('numpy: {}'.format(numpy.__version__))
# matplotlib
import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))
# pandas
import pandas
print('pandas: {}'.format(pandas.__version__))
# scikit-learn
import sklearn
print('sklearn: {}'.format(sklearn.__version__))
# Out:
# Python: 3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]
# scipy: 1.7.1
# numpy: 1.20.3
# matplotlib: 3.4.3
# pandas: 1.3.4
# sklearn: 0.24.2

# %%
import pandas
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
import pandas as pd

# %%
test44_dataset = pd.read_csv("test44.csv")

# %%
test44_dataset
# Out:
#                   # APP   FACEBOOK   INSTAGRAM   TWITTER   QUORA   LINKEDIN  \
# 0            C Compiler        497         137       139      79         65
# 1            C Tutorial        496         153       127      86         36
# 2           C# Compiler        226          95       846      10         73
# 3           C# Tutorial        349          86       200      11         55
# 4          C++ Compiler        248         129       338      23         68
# 5          C++ Tutorial        429         131       469      63         49
# 6           Calculator+        615          63       122      46         25
# 7             Calendar+        521         149       158      16         29
# 8             Compiler+        502         125       181      78         26
# 9          CSS Tutorial        189         141        99      16         23
# 10        Dart Compiler         35          45       314       1         17
# ...

# %%
print(test44_dataset.describe())
# Out:
#          FACEBOOK   INSTAGRAM     TWITTER      QUORA   LINKEDIN      REDDIT  \
# count   38.000000   38.000000   38.000000  38.000000  38.000000   38.000000
# mean   267.710526   94.394737  187.394737  35.342105  33.921053  193.000000
# std    163.115265   54.949874  155.838194  29.539965  23.507769  196.412143
# min      0.000000    0.000000    0.000000   1.000000   0.000000    0.000000
# 25%    123.750000   48.250000  101.250000  11.000000  16.250000   57.250000
# 50%    263.000000   90.500000  148.500000  25.500000  29.000000  126.500000
# 75%    364.500000  128.250000  222.750000  58.750000  50.500000  224.500000
# max    615.000000  297.000000  846.000000  99.000000  83.000000  772.000000
#
#         SNAPCHAT    YOUTUBE   TIKTOK      EMAIL       OTHER
# count  38.000000  38.000000     38.0  38.000000   38.000000
# mean   22.236842  19.394737      0.0   4.657895   50.868421
# std    21.002489  19.679238      0.0   6.469372   43.926333
# ...

# %%
print(test44_dataset.shape)
# Out:
# (38, 12)

# %%
test44_dataset.hist()
plt.show()

# %%
test44_dataset.plot()
# Out:
# <AxesSubplot:>

# %%
test44_dataset.plot.box()
# Out:
# <AxesSubplot:>

# %%
test44_dataset.hist(bins=50, figsize=(15,15))
plt.show()

# %%
axs = test44_dataset.plot.area(figsize=(21, 18), subplots=True)

# %%
import seaborn as sns

# %%
sns.displot(test44_dataset)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
 
df = pd.DataFrame(np.random.randn(1000, 2), columns =['a', 'b'])
 
df.plot.hexbin(x ='a', y ='b', gridsize = 25)
plt.show()

# %%
import pandas as pd
test44_dataset = pd.read_csv("test44.csv")
df = pd.read_csv("test44.csv")

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
test44_dataset = pd.read_csv("test44.csv")
df = pd.DataFrame(np.random.rand(500, 4),
                   columns =['a', 'b', 'c', 'd'])
 
df.plot.scatter(x ='a', y ='b')
plt.show()

# %%
from matplotlib import pyplot as plt
test44_dataset = pd.read_csv("test44.csv")
# x-axis values
x = ["APP"]
  
# Y-axis values
y = ["FACEBOOK", "INSTAGRAM", "TWITTER", "QUORA", "LINKEDIN", "REDDIT", "SNAPCHAT", "YOUTUBE", "TIKTOK", "EMAIL", "OTHER"]
# Function to plot
plt.bar(x,y)
  
# function to show the plot
plt.show()
